# %% [markdown]
# ### Date updated
# 2024-01-04
#
# ### Authors
# Reshama S
#
# ### Instructions for Whisper
# - https://github.com/openai/whisper
# - Setting up virtual environment: https://packaging.python.org/en/latest/guides/installing-using-pip-and-virtual-environments/

# %%
import whisper
import os

# %%
data_dir = "../data/recordings/"
transc_dir = "../data/transcripts/"

# %%
# model options: https://github.com/openai/whisper?tab=readme-ov-file#available-models-and-languages

def audio_scribe(logp, file_name ):
    #model = whisper.load_model("base")
    #model = whisper.load_model("base.en")
    model = whisper.load_model("large")

    filepath = os.path.join(data_dir, file_name)     
    result = model.transcribe(filepath, fp16=False)

    root, ext = os.path.splitext(file_name)
    with open(transc_dir+root+ '.txt', 'w') as f:
        f.write(result['text'])
           
    if logp==1:
        print(file_name)
        #print(type(result))
        #for key, value in result.items():
        #    print(key, value)
    
        print(result["text"])

#audio_scribe(logp=1, file_name='AJ_IMG_3334.MOV')

for filename in os.listdir(data_dir):
    audio_scribe(logp=1, file_name=filename)
# Out:
# 100%|█████████████████████████████████████| 2.88G/2.88G [05:49<00:00, 8.83MiB/s]
# AJ_IMG_3334.MOV
# ...

# %%
import whisper

model = whisper.load_model("base")

# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("../data/audio/AJ_IMG_3334.MOV")
audio = whisper.pad_or_trim(audio)

# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")

# %%
import evaluate

# %%
# load the metric (from Hugging Face)
rouge = evaluate.load('rouge')

predictions = ["hello there", "general kenobi"]
references = ["hello there", "general kenobi"]
results = rouge.compute(predictions=predictions,
                         references=references)
print(results)
# Out:
# {'rouge1': 1.0, 'rouge2': 1.0, 'rougeL': 1.0, 'rougeLsum': 1.0}

# %%
predictions = ["My name is Mrs Reshama"]
references = ["My name is Rachel"]
results = rouge.compute(predictions=predictions,
                         references=references)
print(results)
# Out:
# {'rouge1': 0.6666666666666665, 'rouge2': 0.5714285714285715, 'rougeL': 0.6666666666666665, 'rougeLsum': 0.6666666666666665}

# %%
# decode the audio
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# %%
output1_sladjana = "Well, we went to Italy. I enjoyed Italy, enjoyed the food. I enjoyed the wine and the women are fantastic. 
Um its not the safest place in the world but you kind of live with, you kind you live with. You know you're supposed to lock your house and close your windows and all that staff. Okay. And but everything was fine I mean. No, I lived there.
Stayed there for about three years. Naples. Lovely place. But like I said its not, its not the safest place to live. I spoke a little bit, yeah, a little bit. Yes I did. I worked at the gym. She yeah she was uh, uh she ran a tourist place, you know where people want to take a trip.
She had a lot of people to work for her but people want to take a trip or whatever and she set it up.
